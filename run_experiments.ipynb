# %% [markdown]
# # AdaBoost Experiments

# %%
# from pathlib import Path
# import sys
# import numpy as np
# from sklearn.datasets import make_moons
# from sklearn.model_selection import train_test_split
# 
# from src.adaboost import AdaBoost
# 
# X, y = make_moons(n_samples=300, noise=0.25, random_state=42)
# X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=42)
# 
# model = AdaBoost(n_estimators=100, random_state=42)
# model.fit(X_tr, y_tr)
# acc = model.score(X_te, y_te)
# print(f"Test accuracy: {acc:.4f}")

# %%
#  Training Error Bound theo lý thuyết và thực nghiệm của AdaBoost cần có đồ thị để kiểm chứng 
# có thể vẽ thêm đồ thị của exponential loss để thấy được sự tương quan
# metric tóm tắt ví dụ min margin hoặc % điểm có margin > θ theo T  để "nhận xét và kiểm chứng"ss
